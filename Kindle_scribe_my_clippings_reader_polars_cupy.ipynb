# %% [markdown]
# This notebook ingests the `My Clippings scribe.txt` file from the Kindle Scribe (located in the '/Documents' folder on your Kindle). You need to manually copy the file from your Kindle by connecting it to your PC and then uploading it to the Colab directory.  The result is a more useful database with:
#
# + `source` (the book, pdf or other source)
#
# + `reference` (details of the reference: page, location, date of clipping)
#
# + `quote` (the actual text clipped on the Kindle--for the Scribe it can span more than 1 line and thus required re-writing the original for the Paperwhite!)
#
# columns that can be easily explored. You can, for example, display all quotes from a `source` or search `quote` for particular search terms, including using 'A or B' or 'A and B' search logic. Very basic machine learning is used to summarise topics found in the clippings.
#
# The second part of the notebook automatically generates vocabulary words from single word quotes (when you highlight only one word in your Kindle). This permits an automatic collection of new vocabulary words (and, optionally, combination with an existing list of vocabulary words). A separate notebook, `oxford dictionary lookup.ipynb` automatically looks up the definition of words using the Oxford dictionary API (which you will need to register for and obtain). While the API is free, there are limits to the number of words that can be looked up.
#
# You will need the following files in the base directory:
# - `My Clippings scribe.txt`
# - current vocabulary words in a csv file (you can import old vocabulary words here using a spreadsheet for example)
# - `blank.csv` if a vocabulary file is not available
#
# The vocabulary portion will save the new vocabulary words to `Kindle_scribe_vocab.csv`. It will then load up previously saved vocabulary words found in `Kindle_scribe_vocab_updated.csv`. If this Jupyter notebook has not been run before, the `Kindle_scribe_vocab_updated.csv` file will not exist and the notebook will look for a base vocabulary file (`2DoList.csv`) failing which it will load up a blank.csv file. If you wish to add your existing vocabulary words with definitions, save them to a csv file format using a spreadsheet and save them as `2DoList.csv` (or modify the base vocabulary file name accordingly in the notebook).
#
# This notebook has been tested to run in Colab. If you want to run it locally, you will need to install any dependencies not in your environment.
#
# This is version 2, updated to handle the multi-line quotes in the Kindle Scribe. (py310 conda env)

# %%
import polars as pl
#import numpy as np
import cupy as np
colspecs = [(None, None)]
kindle_clipping_file="My Clippings scribe.txt"
data = pl.read_csv(kindle_clipping_file, columns=[0], has_header=False)
with pl.Config(fmt_str_lengths=300, tbl_rows=30):
    display(data)
# Out:
# shape: (2_225, 1)
# ┌──────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ column_1                                                                                         │
# │ ---                                                                                              │
# │ str                                                                                              │
# ╞══════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ As Twitter destroys its brand by renaming itself X                                               │
# │ - Your Highlight on Location 12-12 | Added on Thursday                                           │
# │ reached 2.1 million                                                                              │
# │ ==========                                                                                       │
# │ These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity         │
# │ Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)                                       │
# │ - Your Highlight on page 142 | Location 2164-2166 | Added on Thursday                            │
# │ The GNC trade generated more than 100 percent profit to Apollo. Then the retailer issued shares  │
# │ to the public in 2011                                                                            │
# │ ==========                                                                                       │
# │ These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity         │
# │ Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)                                       │
# │ - Your Highlight on page 142 | Location 2175-2176 | Added on Thursday                            │
# │ Boom times ended with a hard stop in 2008                                                        │
# │ ==========                                                                                       │
# │ These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity         │
# │ Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)                                       │
# │ - Your Highlight on page 227 | Location 3475-3478 | Added on Thursday                            │
# │ Another former worker at the facility reported that management repeatedly put off repairs to     │
# │ keep costs low                                                                                   │
# │ …                                                                                                │
# │ NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy                                  │
# │ - Your Highlight on Location 64-66 | Added on Thursday                                           │
# │ “Iowa Sen. Charles E. Grassley                                                                   │
# │ ==========                                                                                       │
# │ NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy                                  │
# │ - Your Highlight on Location 172-179 | Added on Thursday                                         │
# │ It may be                                                                                        │
# │ ==========                                                                                       │
# │ d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)                                 │
# │ - Your Highlight on Location 18-19 | Added on Thursday                                           │
# │ It features 256 compute engines per chiplet                                                      │
# │ ==========                                                                                       │
# │ d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)                                 │
# │ - Your Highlight on Location 20-22 | Added on Thursday                                           │
# │ -Matrix CEO Sid Sheth explained that his team has managed to collapse the cache and compute into │
# │ a single construct. "Our compute engine is the cache. Each of them can hold weights and can      │
# │ compute                                                                                          │
# └──────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
# ai suggestion modified:

def categorize_dataframe(df):

    # Initialize empty df to store the values
    source = pl.DataFrame({
        'source': [""]
    })

    reference = pl.DataFrame({
        'reference': [""]
    })

    quote = pl.DataFrame({
        'quote': ['']
    })


    # Initialize a counter
    counter = 0
    quote_count = 0
    holder = ""


    # go through dataframe to extract source, reference and quote
    for value in data['column_1']:

        # deal with empty quote line
        if counter == 2: 
            if value == '==========':

                new_row = pl.DataFrame({
                    'quote': [""]
                })
                quote = quote.vstack(new_row)


        #######################################################
        # normal operations:

        if counter == 0:
            new_row = pl.DataFrame({
                'source': [value]
            })
            new_row = new_row.with_columns(new_row["source"].cast(pl.datatypes.Utf8))
            source = source.vstack(new_row)
            counter += 1
            
        elif counter == 1:
            new_row = pl.DataFrame({
                'reference': [value]
            })
            new_row = new_row.with_columns(new_row["reference"].cast(pl.datatypes.Utf8))
            reference = reference.vstack(new_row)
            counter += 1
            
        else:
            # for quote, need to handle multi line quotes, combine them to one line
            # otherwise they cannot be joined with other columns

            if not (value == '=========='):
                quote_count +=1
                # combine strings to holder
                # needed str(holder) + str(value) instead of holder + str
                # because rapids threw up error about empty str
                # but no error on py310 conda env!
                holder = str(holder) + str(value)
                # print(holder, quote_count)
                list_holder = holder[:]
                new_row = pl.DataFrame({
                    'quote': [list_holder]
                })
                new_row = new_row.with_columns(new_row["quote"].cast(pl.datatypes.Utf8))

                # update quote normally if quote_count is not > 1:
                if quote_count == 1:
                    quote = quote.vstack(new_row)

                # if multiline and quote_count > 1: slice off last row before updating
                elif quote_count > 1:
                    # print(list_holder, quote_count)
                    # update previous row to avoid duplication
                    quote = quote[:-1]
                    quote = quote.vstack(new_row)
                
                counter += 1
                
                    
            else:   # hit delimiter '==========='
                quote_count = 0
                #counter += 1

        ################################################
        if value == '==========':
            counter = 0
            holder = ""
            continue
    

    # combine source, reference, quote into new_df
    new_df = source[1:].hstack(reference[1:])
    new_df = new_df.hstack(quote[1:])
    return new_df


new_df = categorize_dataframe(data)

# %%
with pl.Config(fmt_str_lengths=500, tbl_rows=30):
    display(new_df)
# Out:
# shape: (556, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ source                         ┆ reference                      ┆ quote                          │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ As Twitter destroys its brand  ┆ - Your Highlight on Location   ┆ reached 2.1 million            │
# │ by renaming itself X           ┆ 12-12 | Added on Thursday      ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 142 | ┆ The GNC trade generated more   │
# │ Private Equity Runs—and        ┆ Location 2164-2166 | Added on  ┆ than 100 percent profit to     │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆ Apollo. Then the retailer      │
# │ Equity Runs—and Wrecks—America ┆                                ┆ issued shares to the public in │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆ 2011                           │
# │ Rosner)                        ┆                                ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 142 | ┆ Boom times ended with a hard   │
# │ Private Equity Runs—and        ┆ Location 2175-2176 | Added on  ┆ stop in 2008                   │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆                                │
# │ Equity Runs—and Wrecks—America ┆                                ┆                                │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆                                │
# │ Rosner)                        ┆                                ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 227 | ┆ Another former worker at the   │
# │ Private Equity Runs—and        ┆ Location 3475-3478 | Added on  ┆ facility reported that         │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆ management repeatedly put off  │
# │ Equity Runs—and Wrecks—America ┆                                ┆ repairs to keep costs low      │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆                                │
# │ Rosner)                        ┆                                ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 228 | ┆ “It’s a horrific thing to ask  │
# │ Private Equity Runs—and        ┆ Location 3486-3488 | Added on  ┆ the family member to do        │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆                                │
# │ Equity Runs—and Wrecks—America ┆                                ┆                                │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆                                │
# │ Rosner)                        ┆                                ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 231 | ┆ “Even when you say something   │
# │ Private Equity Runs—and        ┆ Location 3529-3531 | Added on  ┆ is unsafe there’s little       │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆ change that comes out of it    │
# │ Equity Runs—and Wrecks—America ┆                                ┆                                │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆                                │
# │ Rosner)                        ┆                                ┆                                │
# │ These Are the Plunderers: How  ┆ - Your Highlight on page 232 | ┆ Once the privateers recognized │
# │ Private Equity Runs—and        ┆ Location 3543-3544 | Added on  ┆ that the Federal Reserve Board │
# │ Wrecks—America: How Private    ┆ Thursday                       ┆ stood ready to bail them out   │
# │ Equity Runs—and Wrecks—America ┆                                ┆ of bad trades                  │
# │ (Gretchen Morgenson;Joshua     ┆                                ┆                                │
# │ Rosner)                        ┆                                ┆                                │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ Cai Fang                       │
# │ becoming more dangerous by the ┆ 13-14 | Added on Thursday      ┆                                │
# │ day (www.telegraph.co.uk)      ┆                                ┆                                │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ The effect is to bludgeon a    │
# │ becoming more dangerous by the ┆ 22-24 | Added on Thursday      ┆ eurozone economy already in a  │
# │ day (www.telegraph.co.uk)      ┆                                ┆ deep industrial recession. The │
# │                                ┆                                ┆ cheaper the yuan               │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ The Chinese endured draconian  │
# │ becoming more dangerous by the ┆ 25-27 | Added on Thursday      ┆ lockdowns for three years with │
# │ day (www.telegraph.co.uk)      ┆                                ┆ far less support. The damage   │
# │                                ┆                                ┆ has undermined the finances of │
# │                                ┆                                ┆ millions of small family       │
# │                                ┆                                ┆ businesses. A large chunk of   │
# │                                ┆                                ┆ the population has slashed     │
# │                                ┆                                ┆ spending in order to rebuild   │
# │                                ┆                                ┆ depleted savings.              │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ great Communist debt bubble    │
# │ becoming more dangerous by the ┆ 28-28 | Added on Thursday      ┆                                │
# │ day (www.telegraph.co.uk)      ┆                                ┆                                │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ The giant developer Country    │
# │ becoming more dangerous by the ┆ 29-31 | Added on Thursday      ┆ Garden                         │
# │ day (www.telegraph.co.uk)      ┆                                ┆                                │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ “We believe the Chinese        │
# │ becoming more dangerous by the ┆ 35-35 | Added on Thursday      ┆ economy is faced with an       │
# │ day (www.telegraph.co.uk)      ┆                                ┆ imminent downward spiral with  │
# │                                ┆                                ┆ the worst yet to come          │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ China’s $60 trillion property  │
# │ becoming more dangerous by the ┆ 38-41 | Added on Thursday      ┆ edifice is by far the largest  │
# │ day (www.telegraph.co.uk)      ┆                                ┆ asset class in the world.  It  │
# │                                ┆                                ┆ accounts for half of the       │
# │                                ┆                                ┆ world’s entire property sales  │
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ The developers have debts of   │
# │ becoming more dangerous by the ┆ 41-42 | Added on Thursday      ┆ $5 trillion. By comparison     │
# │ day (www.telegraph.co.uk)      ┆                                ┆                                │
# │ …                              ┆ …                              ┆ …                              │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ Spotify spent its way to the   │
# │ 06-09-2023 (Sony)              ┆ 111-114 | Added on Wednesday   ┆ top of an industry that turned │
# │ (NewspaperDirect)              ┆                                ┆ out to be less lucrative than  │
# │                                ┆                                ┆ it appeared when it began its  │
# │                                ┆                                ┆ podcast quest in 2018. “The    │
# │                                ┆                                ┆ size of the bet up against the │
# │                                ┆                                ┆ size of the market just seems  │
# │                                ┆                                ┆ irrational in retrospect       │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ The unusual loan is the latest │
# │ 06-09-2023 (Sony)              ┆ 218-220 | Added on Wednesday   ┆ example of how the world’s     │
# │ (NewspaperDirect)              ┆                                ┆ richest man has drummed up     │
# │                                ┆                                ┆ cash from his empire of        │
# │                                ┆                                ┆ companies without having to    │
# │                                ┆                                ┆ permanently part with          │
# │                                ┆                                ┆ shares—enabling him to raise   │
# │                                ┆                                ┆ funds for his wide array of    │
# │                                ┆                                ┆ endeavors.                     │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ SpaceX had $4.7 billion in     │
# │ 06-09-2023 (Sony)              ┆ 232-234 | Added on Wednesday   ┆ cash and securities on hand at │
# │ (NewspaperDirect)              ┆                                ┆ the end of last year           │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ In November                    │
# │ 06-09-2023 (Sony)              ┆ 234-236 | Added on Wednesday   ┆                                │
# │ (NewspaperDirect)              ┆                                ┆                                │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ Musk has said he would be      │
# │ 06-09-2023 (Sony)              ┆ 236-237 | Added on Wednesday   ┆ paying more than $11 billion   │
# │ (NewspaperDirect)              ┆                                ┆ in taxes for 2021 and he put   │
# │                                ┆                                ┆ up about $25 billion in cash   │
# │                                ┆                                ┆ as part of his $44 billion     │
# │                                ┆                                ┆ deal to acquire Twitter        │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ From the early days of SpaceX  │
# │ 06-09-2023 (Sony)              ┆ 237-239 | Added on Wednesday   ┆                                │
# │ (NewspaperDirect)              ┆                                ┆                                │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ As of December 2020            │
# │ 06-09-2023 (Sony)              ┆ 245-247 | Added on Wednesday   ┆                                │
# │ (NewspaperDirect)              ┆                                ┆                                │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ An early plan called for Musk  │
# │ 06-09-2023 (Sony)              ┆ 259-260 | Added on Thursday    ┆ to borrow $12.5 billion        │
# │ (NewspaperDirect)              ┆                                ┆ through loans backed by Tesla  │
# │                                ┆                                ┆ shares he owned that at the    │
# │                                ┆                                ┆ time were valued at more than  │
# │                                ┆                                ┆ $62.5 billion                  │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ The idea worried some          │
# │ 06-09-2023 (Sony)              ┆ 260-262 | Added on Thursday    ┆ investors. Tesla’s board and   │
# │ (NewspaperDirect)              ┆                                ┆ several banks had put in place │
# │                                ┆                                ┆ rules that required him to put │
# │                                ┆                                ┆ up more collateral were        │
# │                                ┆                                ┆ Tesla’s share price to fall.   │
# │                                ┆                                ┆ And it was falling in those    │
# │                                ┆                                ┆ days                           │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ The Warren Buffett-backed      │
# │ 06-09-2023 (Sony)              ┆ 3588-3593 | Added on Thursday  ┆ Chinese automaker sold 1.8     │
# │ (NewspaperDirect)              ┆                                ┆ million new-energy vehicles    │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ BYD’s formula for success in   │
# │ 06-09-2023 (Sony)              ┆ 3597-3600 | Added on Thursday  ┆ its home country could likely  │
# │ (NewspaperDirect)              ┆                                ┆ work outside China             │
# │ NEW: The Coming Collapse of    ┆ - Your Highlight on Location   ┆ “Iowa Sen. Charles E. Grassley │
# │ Donald Trump’s January 6       ┆ 64-66 | Added on Thursday      ┆                                │
# │ Conspiracy                     ┆                                ┆                                │
# │ NEW: The Coming Collapse of    ┆ - Your Highlight on Location   ┆ It may be                      │
# │ Donald Trump’s January 6       ┆ 172-179 | Added on Thursday    ┆                                │
# │ Conspiracy                     ┆                                ┆                                │
# │ d-Matrix scores $110M to       ┆ - Your Highlight on Location   ┆ It features 256 compute        │
# │ undercut Nvidia in AI          ┆ 18-19 | Added on Thursday      ┆ engines per chiplet            │
# │ (theregister.com)              ┆                                ┆                                │
# │ d-Matrix scores $110M to       ┆ - Your Highlight on Location   ┆ -Matrix CEO Sid Sheth          │
# │ undercut Nvidia in AI          ┆ 20-22 | Added on Thursday      ┆ explained that his team has    │
# │ (theregister.com)              ┆                                ┆ managed to collapse the cache  │
# │                                ┆                                ┆ and compute into a single      │
# │                                ┆                                ┆ construct. "Our compute engine │
# │                                ┆                                ┆ is the cache. Each of them can │
# │                                ┆                                ┆ hold weights and can compute   │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %%
# source is [:,0], reference is [:,1], quote is [:,2]
with pl.Config(fmt_str_lengths=500):
    display(new_df[:,0])
# Out:
# shape: (556,)
# Series: 'source' [str]
# [
# 	"As Twitter destroys its brand by renaming itself X"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"China’s property crash is becoming more dangerous by the day (www.telegraph.co.uk)"
# 	"China’s property crash is becoming more dangerous by the day (www.telegraph.co.uk)"
# 	"China’s property crash is becoming more dangerous by the day (www.telegraph.co.uk)"
# 	"China’s property crash is becoming more dangerous by the day (www.telegraph.co.uk)"
# 	"China’s property crash is becoming more dangerous by the day (www.telegraph.co.uk)"
# 	…
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)"
# 	"NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy"
# 	"NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy"
# 	"d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)"
# 	"d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)"
# ]

# %%
# test: for a specific quote, print source, highlight detail and quote
# repeat until last

quote_number=480
while quote_number < new_df.shape[0]:
      print(new_df[quote_number, 0] + '\n',   
      new_df[quote_number, 1] + '\n',
      new_df[quote_number,2] + '\n')

      quote_number += 1
# Out:
# Speed
#  - Your Highlight on Location 147-148 | Added on Wednesday
#  We find that without CUDA graphs
#
# When the generative AI hype fades (Matt Asay)
#  - Your Highlight on Location 16-19 | Added on Wednesday
#  Once all the hype around GenAI fades—and it will—we’ll be left with increased investments in deep learning and machine learning
#
# When the generative AI hype fades (Matt Asay)
#  - Your Highlight on Location 36-38 | Added on Wednesday
#  “Small
#
# When the generative AI hype fades (Matt Asay)
#  - Your Highlight on Location 58-61 | Added on Wednesday
#  But GenAI is a subset of a subset of a subset of AI
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 178-182 | Added on Wednesday
#  Arm published a prospectus for its blockbuster IPO on the Nasdaq exchange next month. SoftBank
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 182-184 | Added on Wednesday
#  The superlatives came thick and fast when Nvidia released quarterly earnings. Revenue more than doubled at the maker of chips for AI
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 194-195 | Added on Wednesday
#  The yield on American ten-year government bonds hit a 16-year high
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 245-246 | Added on Wednesday
#  During each episode
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 265-268 | Added on Wednesday
#  The top ranks of government still contain plenty of talent
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 272-274 | Added on Wednesday
#  But China is now testing the reverse relationship: whether more autocracy damages the economy. The evidence is mounting that it does—and that after four decades of fast growth China is entering a period of disappointment.
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3537-3539 | Added on Wednesday
#  SoftBank paid $16bn for a 25% stake which was held by the group’s Vision Fund
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3550-3551 | Added on Wednesday
#  as ai moves from data centres to consumer apps
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3552-3555 | Added on Wednesday
#  Most of Arm’s sales come from processors for smartphones
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3555-3558 | Added on Wednesday
#  Arm’s position as the only supplier of easy-to-use chip designs is also in peril from risc-v
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 4353-4354 | Added on Wednesday
#  In 2021 the 200 biggest multinationals in America
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 4363-4367 | Added on Wednesday
#  But what if things go badly wrong in China? Under a worst-case scenario
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 4390-4392 | Added on Wednesday
#  Recent data suggest it may even be on track for annualised growth of nearly 6% in the third quarter
#
# the-economist 26-08-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 4745-4746 | Added on Wednesday
#  The first semi-solid batteries should appear in cars in 2025-26
#
# Adani family's partners used 'opaque' funds to invest in its stocks - media group (Amazon)
#  - Your Highlight on Location 15-18 | Added on Wednesday
#  The OCCRP article comes after U.S.-based short-seller Hindenburg Research in January accused Adani Group of improper business dealings
#
# Hands-On GPU Programming with Python and CUDA - Unknown
#  - Your Highlight on page 51-51 | Added on Wednesday
#  NVIDIA includes a command-line example written in pure CUDA-C called deviceQuery
#
# The Odyssey (Homer)
#  - Your Highlight on Location 2030-2030 | Added on Monday
#  Aegyptius
#
# China’s Biggest Homebuilder Reels as Economy Slows (Claire Fu)
#  - Your Highlight on Location 17-19 | Added on Monday
#  Country Garden
#
# China’s Biggest Homebuilder Reels as Economy Slows (Claire Fu)
#  - Your Highlight on Location 22-24 | Added on Monday
#  last-minute approval from creditors to postpone repayment of $537 million in yuan-denominated bonds
#
# China’s Biggest Homebuilder Reels as Economy Slows (Claire Fu)
#  - Your Highlight on Location 57-58 | Added on Monday
#  The company succeeded with a high turnover strategy: build fast
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 51-51 | Added on Monday
#  Vectorized computing eliminates the need for many explicit loops over the array elements by applying batch operations on the array data
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 51-51 | Added on Monday
#  Vectorized computations can therefore be significantly faster than sequential element-by-element computations
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 52-52 | Added on Monday
#  NumPy provides the numerical backend for nearly every scientific or technical library for Python. It is therefore a very important part of the scientific Python ecosystem
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 192-194 | Added on Tuesday
#  Stock-market bulls are on edge heading into September as investors are questioning whether stocks can continue defying expectations and hang on to this year’s gains so far.
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 229-231 | Added on Tuesday
#  The federal money—tied to industrial production that brings jobs—is beginning to sway even the most coal-centric areas of the country. The funds have reframed the renewable-energy debate away from global warming and environmental protection
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 251-253 | Added on Tuesday
#  The state approved in December a hydrogen factory to be built by Houston renewables company Fidelis New Energy. Last month it approved up to $62.5 million in loans for the project
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 256-258 | Added on Tuesday
#  Evan Hansen
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 261-264 | Added on Tuesday
#  She landed on Ravenswood
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 272-273 | Added on Tuesday
#  A plan took shape: A new solar farm constructed by BHE will provide clean energy to a new titanium facility built by Berkshire’s Precision Castparts. Batteries designed by ONE will help provide stable power to the plant. The titanium facility is expected to open in early 2025.
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 330-332 | Added on Tuesday
#  “The Chinese government is engaged in a broad
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3131-3133 | Added on Tuesday
#  Automakers bagged funding from Volkswagen and Intel
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3140-3142 | Added on Tuesday
#  For more than a decade
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3142-3144 | Added on Tuesday
#  One in four new cars sold in China last year was electric or plug-in
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3238-3240 | Added on Tuesday
#  The S&P 500 is up 18% so far this year
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3247-3249 | Added on Tuesday
#  Sissel said stocks are overvalued and she expects the S&P 500 to decline more than 10% from its current level by the end of the year. Companies in the index are trading at about 19 times their projected earnings over the next 12 months
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3259-3260 | Added on Tuesday
#  Institutional investors are cashing in on their gains
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3263-3264 | Added on Tuesday
#  “These tech megacaps went up too far too fast—the AI hype had a lot to do with it
#
# the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3283-3284 | Added on Tuesday
#  Novo Nordisk’s shares edged higher
#
# news2 (ibkr.com)
#  - Your Highlight on Location 10-13 | Added on Tuesday
#  Tower will invest up to $300 million to acquire and own equipment and other fixed assets to be installed in the New Mexico facility
#
# news2 (ibkr.com)
#  - Your Highlight on Location 20-21 | Added on Tuesday
#  world’s first open system foundry that brings together a secure
#
# news2 (ibkr.com)
#  - Your Highlight on Location 35-38 | Added on Tuesday
#  IFS is a critical pillar of Intel’s IDM 2.0 strategy
#
# The New York Times - calibre (calibre)
#  - Your Highlight on Location 1264-1266 | Added on Tuesday
#  BYD
#
# The New York Times - calibre (calibre)
#  - Your Highlight on Location 1297-1298 | Added on Tuesday
#  But the source of that power was natural gas piped in from Russia
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 52-52 | Added on Tuesday
#  homogeneous data
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 52-52 | Added on Tuesday
#  A full list of attributes with descriptions is available in the ndarray docstring
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 55-55 | Added on Tuesday
#  programming language
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 56-56 | Added on Tuesday
#  For efficiency
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 57-57 | Added on Tuesday
#  Creates an array with evenly spaced values between the specified start
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 60-60 | Added on Tuesday
#  In numerical computing it is very common to require arrays with evenly spaced values between a starting value and ending value. NumPy provides two similar functions to create such arrays: np.arange and np.linspace. Both functions take three arguments
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 60-60 | Added on Tuesday
#  generally recommended to use np.linspace whenever the increment is a noninteger
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 62-62 | Added on Tuesday
#  It is often necessary to create new arrays that share properties
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 62-62 | Added on Tuesday
#  NumPy provides functions for generating commonly used matrices. In particular
#
# Numerical Python Scientific Computing and Data Science Applications with Numpy SciPy and Matplotlib - Unknown
#  - Your Highlight on page 64-64 | Added on Tuesday
#  Select elements with index m through n (exclusive)
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 67-70 | Added on Wednesday
#  Nearly a decade into their electric-vehicle shift
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 81-82 | Added on Wednesday
#  last year China pulled ahead of Germany and the U.S. for the first time in the number of technological advancements in areas such as batteries
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 83-84 | Added on Wednesday
#  The biggest challenges for the German auto industry are its lack of software competence and the fact that its cars are more expensive
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 89-92 | Added on Wednesday
#  UBS said BYD would likely have a long-term cost advantage of around 25% over traditional auto manufacturers. After Chinese brands turned the tables on their foreign competition in China
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 111-114 | Added on Wednesday
#  Spotify spent its way to the top of an industry that turned out to be less lucrative than it appeared when it began its podcast quest in 2018. “The size of the bet up against the size of the market just seems irrational in retrospect
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 218-220 | Added on Wednesday
#  The unusual loan is the latest example of how the world’s richest man has drummed up cash from his empire of companies without having to permanently part with shares—enabling him to raise funds for his wide array of endeavors.
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 232-234 | Added on Wednesday
#  SpaceX had $4.7 billion in cash and securities on hand at the end of last year
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 234-236 | Added on Wednesday
#  In November
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 236-237 | Added on Wednesday
#  Musk has said he would be paying more than $11 billion in taxes for 2021 and he put up about $25 billion in cash as part of his $44 billion deal to acquire Twitter
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 237-239 | Added on Wednesday
#  From the early days of SpaceX
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 245-247 | Added on Wednesday
#  As of December 2020
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 259-260 | Added on Thursday
#  An early plan called for Musk to borrow $12.5 billion through loans backed by Tesla shares he owned that at the time were valued at more than $62.5 billion
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 260-262 | Added on Thursday
#  The idea worried some investors. Tesla’s board and several banks had put in place rules that required him to put up more collateral were Tesla’s share price to fall. And it was falling in those days
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3588-3593 | Added on Thursday
#  The Warren Buffett-backed Chinese automaker sold 1.8 million new-energy vehicles
#
# the-wall-street-journal 06-09-2023 (Sony) (NewspaperDirect)
#  - Your Highlight on Location 3597-3600 | Added on Thursday
#  BYD’s formula for success in its home country could likely work outside China
#
# NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy
#  - Your Highlight on Location 64-66 | Added on Thursday
#  “Iowa Sen. Charles E. Grassley
#
# NEW: The Coming Collapse of Donald Trump’s January 6 Conspiracy
#  - Your Highlight on Location 172-179 | Added on Thursday
#  It may be
#
# d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)
#  - Your Highlight on Location 18-19 | Added on Thursday
#  It features 256 compute engines per chiplet
#
# d-Matrix scores $110M to undercut Nvidia in AI (theregister.com)
#  - Your Highlight on Location 20-22 | Added on Thursday
#  -Matrix CEO Sid Sheth explained that his team has managed to collapse the cache and compute into a single construct. "Our compute engine is the cache. Each of them can hold weights and can compute

# %%
# output all the unique sources used in Kindle clippings
with pl.Config(fmt_str_lengths=200):
    display(new_df[:,0].unique())
# Out:
# shape: (44,)
# Series: 'source' [str]
# [
# 	"The Economist (calibre)"
# 	"Death Will Come for the Cult of MAGA - The Atlantic (theatlantic.com)"
# 	"Rising rates and “capital deprivation” Financial Times (Unknown)"
# 	"natural language processing with pytorch - Unknown  "
# 	"The New York Times - calibre (calibre)"
# 	"Tesla&#39;s Value Plunged Nearly $200 Billion in Just a Few Weeks (markets.businessinsider.com)"
# 	"the-wall-street-journal 05-09-2023 (Sony) (NewspaperDirect)"
# 	"The Crisis of Democratic Capitalism (Martin Wolf)"
# 	"The Bad News for Automakers in China Is Only Getting Worse (www.businessinsider.com)"
# 	"These Are the Plunderers: How Private Equity Runs—and Wrecks—America: How Private Equity Runs—and Wrecks—America (Gretchen Morgenson;Joshua Rosner)"
# 	"the-economist 26-08-2023 (Sony) (NewspaperDirect)"
# 	"The Self-Taught Programmer: The Definitive Guide to Programming Professionally (Althoff"
# 	…
# 	"The Odyssey (Homer)"
# 	"China Faces a Crisis in Its Real Estate Sector - The New York Times (www.nytimes.com)"
# 	"China’s Property Crisis Is Rippling Through the Economy - The New York Times (www.nytimes.com)"
# 	"William Shakespeare Complete Works Second Edition (William Shakespeare)"
# 	"The Intelligent Investor"
# 	"the-wall-street-journal 30-08-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 22-08-2023 (Sony) (NewspaperDirect)"
# 	"the-wall-street-journal 29-08-2023 (Sony) (NewspaperDirect)"
# 	"Bloomberg Evening Briefing_ Another Bad Sign for China’s Economy - Bloomberg (www.bloomberg.com)"
# 	"The Wall Street Journal (NewspaperDirect)"
# 	"Adani family's partners used 'opaque' funds to invest in its stocks - media group (Amazon)"
# 	"the-wall-street-journal 23-08-2023 (Sony) (NewspaperDirect)"
# 	"Fluent Python"
# ]

# %%
# save new_df to file for machine learning by other notebooks
# use 'kindle_scribe_new_df.csv' in a separate notebook for machine learning text processing
new_df.write_csv('kindle_scribe_new_df.csv')

# %% [markdown]
# # Set search parameters here
#
# With this Kindle clipping database, you can now define `search_term` and `search_term2`. For example, if you only want to search within Shakespeare books, you can enter 'shakespeare' as `search_term`. Leaving a search term blank searches all instances or sources. You can also be very specific, such as `'tesla | China'` to search for 'tesla' or 'China' in the clipping. If you want both, use `'tesla .* China'`.

# %%
# leave blank to search all sources
# syntax for more than 1 search term?
# (?i) is case insensitive

source_search_term = ('(?i)')
quote_search_term = ('(?i)China')

df_search = new_df.filter(pl.col('source').str.contains(source_search_term))
df_search = df_search.filter(pl.col('quote').str.contains(quote_search_term))

with pl.Config(fmt_str_lengths=500):
    display(df_search[['source','reference','quote']])
# Out:
# shape: (24, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ source                         ┆ reference                      ┆ quote                          │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ China’s property crash is      ┆ - Your Highlight on Location   ┆ China’s $60 trillion property  │
# │ becoming more dangerous by the ┆ 38-41 | Added on Thursday      ┆ edifice is by far the largest  │
# │ day (www.telegraph.co.uk)      ┆                                ┆ asset class in the world.  It  │
# │                                ┆                                ┆ accounts for half of the       │
# │                                ┆                                ┆ world’s entire property sales  │
# │ The Economist (calibre)        ┆ - Your Highlight on page 45 |  ┆ None of this bodes well for    │
# │                                ┆ Location 688-692 | Added on    ┆ China’s dismal fertility rate  │
# │                                ┆ Friday                         ┆ (the number of children a      │
# │                                ┆                                ┆ woman can be expected to have  │
# │                                ┆                                ┆ in her lifetime). It fell to a │
# │                                ┆                                ┆ historic low of 1.2 in         │
# │                                ┆                                ┆ 2021—far below the replacement │
# │                                ┆                                ┆ rate of 2.1. Besides home      │
# │                                ┆                                ┆ prices                         │
# │ The Economist (calibre)        ┆ - Your Highlight on page 97 |  ┆ As China’s economy slows       │
# │                                ┆ Location 1473-1477 | Added on  ┆                                │
# │                                ┆ Friday                         ┆                                │
# │ The Economist (calibre)        ┆ - Your Highlight on page 182 | ┆ CHINA’S ECONOMIC problems are  │
# │                                ┆ Location 2782-2784 | Added on  ┆ distinctive. Inflation is too  │
# │                                ┆ Friday                         ┆ low                            │
# │ …                              ┆ …                              ┆ …                              │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ One in four new cars sold in   │
# │ 05-09-2023 (Sony)              ┆ 3142-3144 | Added on Tuesday   ┆ China last year was electric   │
# │ (NewspaperDirect)              ┆                                ┆ or plug-in                     │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ last year China pulled ahead   │
# │ 06-09-2023 (Sony)              ┆ 81-82 | Added on Wednesday     ┆ of Germany and the U.S. for    │
# │ (NewspaperDirect)              ┆                                ┆ the first time in the number   │
# │                                ┆                                ┆ of technological advancements  │
# │                                ┆                                ┆ in areas such as batteries     │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ UBS said BYD would likely have │
# │ 06-09-2023 (Sony)              ┆ 89-92 | Added on Wednesday     ┆ a long-term cost advantage of  │
# │ (NewspaperDirect)              ┆                                ┆ around 25% over traditional    │
# │                                ┆                                ┆ auto manufacturers. After      │
# │                                ┆                                ┆ Chinese brands turned the      │
# │                                ┆                                ┆ tables on their foreign        │
# │                                ┆                                ┆ competition in China           │
# │ the-wall-street-journal        ┆ - Your Highlight on Location   ┆ BYD’s formula for success in   │
# │ 06-09-2023 (Sony)              ┆ 3597-3600 | Added on Thursday  ┆ its home country could likely  │
# │ (NewspaperDirect)              ┆                                ┆ work outside China             │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %%
# used a dataset visualisation example code to display the length of the highlight column

"""Module to explore data.
Contains functions to help study, visualize and understand datasets.
https://github.com/google/eng-edu/blob/main/ml/guides/text_classification/explore_data.py
"""
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import matplotlib.pyplot as plt

from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer


def get_num_classes(labels):
    """Gets the total number of classes.
    # Arguments
        labels: list, label values.
            There should be at lease one sample for values in the
            range (0, num_classes -1)
    # Returns
        int, total number of classes.
    # Raises
        ValueError: if any label value in the range(0, num_classes - 1)
            is missing or if number of classes is <= 1.
    """
    num_classes = max(labels) + 1
    missing_classes = [i for i in range(num_classes) if i not in labels]
    if len(missing_classes):
        raise ValueError('Missing samples with label value(s) '
                         '{missing_classes}. Please make sure you have '
                         'at least one sample for every label value '
                         'in the range(0, {max_class})'.format(
                            missing_classes=missing_classes,
                            max_class=num_classes - 1))

    if num_classes <= 1:
        raise ValueError('Invalid number of labels: {num_classes}.'
                         'Please make sure there are at least two classes '
                         'of samples'.format(num_classes=num_classes))
    return num_classes


def get_num_words_per_sample(sample_texts):
    """Gets the median number of words per sample given corpus.
    # Arguments
        sample_texts: list, sample texts.
    # Returns
        int, median number of words per sample.
    """
    num_words = [len(s.split()) for s in sample_texts]
    return np.median(num_words)


def plot_frequency_distribution_of_ngrams(sample_texts,
                                          ngram_range=(1, 2),
                                          num_ngrams=50):
    """Plots the frequency distribution of n-grams.
    # Arguments
        samples_texts: list, sample texts.
        ngram_range: tuple (min, mplt), The range of n-gram values to consider.
            Min and mplt are the lower and upper bound values for the range.
        num_ngrams: int, number of n-grams to plot.
            Top `num_ngrams` frequent n-grams will be plotted.
    """
    # Create args required for vectorizing.
    kwargs = {
            'ngram_range': (1, 1),
            'dtype': 'int32',
            'strip_accents': 'unicode',
            'decode_error': 'replace',
            'analyzer': 'word',  # Split text into word tokens.
    }
    vectorizer = CountVectorizer(**kwargs)

    # This creates a vocabulary (dict, where keys are n-grams and values are
    # idxices). This also converts every text to an array the length of
    # vocabulary, where every element idxicates the count of the n-gram
    # corresponding at that idxex in vocabulary.
    vectorized_texts = vectorizer.fit_transform(sample_texts)

    # This is the list of all n-grams in the index order from the vocabulary.
    all_ngrams = list(vectorizer.get_feature_names())
    num_ngrams = min(num_ngrams, len(all_ngrams))
    # ngrams = all_ngrams[:num_ngrams]

    # Add up the counts per n-gram ie. column-wise
    all_counts = vectorized_texts.sum(axis=0).tolist()[0]

    # Sort n-grams and counts by frequency and get top `num_ngrams` ngrams.
    all_counts, all_ngrams = zip(*[(c, n) for c, n in sorted(
        zip(all_counts, all_ngrams), reverse=True)])
    ngrams = list(all_ngrams)[:num_ngrams]
    counts = list(all_counts)[:num_ngrams]

    idx = np.arange(num_ngrams)
    plt.bar(idx, counts, width=0.8, color='b')
    plt.xlabel('N-grams')
    plt.ylabel('Frequencies')
    plt.title('Frequency distribution of n-grams')
    plt.xticks(idx, ngrams, rotation=45)
    plt.show()


def plot_sample_length_distribution(sample_texts):
    """Plots the sample length distribution.
    # Arguments
        samples_texts: list, sample texts.
    """
    plt.hist([len(s) for s in sample_texts], 50)
    plt.xlabel('Length of a sample')
    plt.ylabel('Number of samples')
    plt.title('Sample length distribution')
    plt.show()

# %%
df = new_df.to_pandas()
plot_sample_length_distribution(df['quote'])

# %% [markdown]
# # Topic generator
# Simple code sample from Bing AI to get an overview of the topics covered in the Kindle clippings.

# %%
# modified sample code from Bing AI to get some overview of the topics
# covered in the Kindle clipping dataset; once you have topics, you can
# conduct boolean searches as shown previously for more detail

# Import the necessary modules
# from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Extract the document-term matrix using CountVectorizer
vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                             max_features=1000,
                             stop_words='english')
X = vectorizer.fit_transform(df['quote'])

# Fit the LDA model with n_components topics
lda = LatentDirichletAllocation(n_components=10, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(X)

# Print the top 10 words for each topic
# feature_names = vectorizer.get_feature_names() bug requires _out() until updated
feature_names = vectorizer.get_feature_names_out()
for topic_idx, topic in enumerate(lda.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join([feature_names[i]
                    for i in topic.argsort()[:-11:-1]]))
    print()
# Out:
# Topic #0:
# tesla np money industry value functions arrays linspace investors just
#
# Topic #1:
# china year time far world million end people billion hinton
#
# Topic #2:
# higher automakers intelligence business intel shares funding artificial various ev
#
# Topic #3:
# year stocks said 10 microsoft companies times months decline treasury
#
# Topic #4:
# company learning neural deep network gpu list 2020 data networks
#
# Topic #5:
# billion ai musk said tesla investors shares 2021 like fast
#
# Topic #6:
# chinese government long term beijing index likely didn broad elements
#
# Topic #7:
# array cash strategy funds shares raise byd empire start world
#
# Topic #8:
# data compute decade nearly cache days early team nvidia built
#
# Topic #9:
# new million facility power energy provide built lab page months

# %% [markdown]
# # Vocabulary generator
#
# Another potentially useful feature is generating vocabulary automatically from the Kindle clippings. The code takes all single word clippings and adds them to the 'Kindle_vocab.csv' file.

# %%
vocabulary = df['quote'].str.strip().str.split(' ').str.len().eq(1)
output = df[vocabulary]
vocab = output.loc[:,('quote')].str.rstrip('.,;?')
df_csv = vocab.to_csv('Kindle_scribe_vocab.csv', index=True)
print('Printed to Kindle_scribe_vocab.csv')
# Out:
# Printed to Kindle_scribe_vocab.csv

# %%
print(vocab)
# Out:
# 31                    Scam
# 51                  fervid
# 91                     RIM
# 110             Krizhevsky
# 119            Recognizing
# 122           Nevertheless
# 189                   Good
# 225              Meanwhile
# 235             Sino-Ocean
# 236                 Indeed
# 240
# 241
# 242                   Then
# 268             Pointless
# 285            Nonetheless
# 286            Nonetheless
# 299                .split(
# 308       “Suburbanization
# 359           Nevertheless
# 385                 Online
# 386                  “Here
# 393                  Tesla
# 469                However
# 473                However
# 478    torch.cuda.Stream()
# 482                 “Small
# 500              Aegyptius
# 525                    BYD
# Name: quote, dtype: object

# %%
# loads updated vocabulary file first. If this is the first time because Kindle clips have not been added
# or the file is missing then load base vocabulary file from 2DoList.csv
# if that file is missing, load blank.csv
# using pandas instead of polars

try:
    main_vocabulary = pl.read_csv("Kindle_scribe_vocab_updated.csv")
except Exception as e:
    print("Kindle_scribe_vocab_updated.csv file not found, loading base file.")
    try:
        main_vocabulary = pl.read_csv("2DoList.csv")     # csv vocabulary file created previously
    except Exception as e:
        main_vocabulary = pl.read_csv("blank.csv")       # empty csv file if no vocabulary files available
main_vocabulary.shape
# Out:
# (988, 2)

# %%
main_vocabulary
# Out:
# shape: (988, 2)
# ┌─────────────────────────┬───────┐
# │ WORD                    ┆  NOTE │
# │ ---                     ┆ ---   │
# │ str                     ┆ str   │
# ╞═════════════════════════╪═══════╡
# │ abaddon                 ┆ null  │
# │ abaft                   ┆ null  │
# │ abba                    ┆ null  │
# │ aberglaube              ┆ null  │
# │ …                       ┆ …     │
# │ Nonetorch.cuda.Stream() ┆ null  │
# │ None“Small              ┆ null  │
# │ NoneAegyptius           ┆ null  │
# │ NoneBYD                 ┆ null  │
# └─────────────────────────┴───────┘

# %%
# make sure index is the same
# polars has trouble here, using pandas for now
vocab = pl.Series(vocab)
vocab.index = np.arange(0, len(vocab) + 0)

# object to dataframe
vocab_add = pl.DataFrame(vocab)

# create same column name
vocab_add.columns = ['WORD']

# %%
# filter for empty entries:
#vocab_add = pl.Series(vocab_add)
#vocab_add.set(vocab_add.str.lengths() == 0, None)
#vocab_add = vocab_add.drop_nulls()
vocab_add = vocab_add.filter(pl.col('WORD') != "")
vocab_add
# Out:
# shape: (26, 1)
# ┌─────────────────────┐
# │ WORD                │
# │ ---                 │
# │ str                 │
# ╞═════════════════════╡
# │ Scam                │
# │ fervid              │
# │ RIM                 │
# │ Krizhevsky          │
# │ …                   │
# │ torch.cuda.Stream() │
# │ “Small              │
# │ Aegyptius           │
# │ BYD                 │
# └─────────────────────┘

# %%
# filter null entries where WORD is null
main_vocabulary = main_vocabulary.filter(pl.col('WORD').is_not_null())
main_vocabulary
# Out:
# shape: (988, 2)
# ┌─────────────────────────┬───────┐
# │ WORD                    ┆  NOTE │
# │ ---                     ┆ ---   │
# │ str                     ┆ str   │
# ╞═════════════════════════╪═══════╡
# │ abaddon                 ┆ null  │
# │ abaft                   ┆ null  │
# │ abba                    ┆ null  │
# │ aberglaube              ┆ null  │
# │ …                       ┆ …     │
# │ Nonetorch.cuda.Stream() ┆ null  │
# │ None“Small              ┆ null  │
# │ NoneAegyptius           ┆ null  │
# │ NoneBYD                 ┆ null  │
# └─────────────────────────┴───────┘

# %%
# to vstack, need same column number in two dataframes

vocab_add = vocab_add.with_columns([
    pl.lit(None).alias(' NOTE').cast(pl.datatypes.Utf8),
])
new_vocabulary = main_vocabulary.vstack(vocab_add)
new_vocabulary
# save to csv
#df_csv = main_vocabulary.to_csv('Kindle_scribe_vocab_updated.csv', index=False)                # index=False as otherwise adding extra index columns
new_vocabulary.write_csv('Kindle_scribe_vocab_updated.csv')
print('Saved new Kindle clipping words to Kindle_scribe_vocab_updated.csv.')
# Out:
# Saved new Kindle clipping words to Kindle_scribe_vocab_updated.csv.

# %%
# update with new words only in pandas
# https://stackoverflow.com/questions/52342627/appending-only-new-values-from-a-dataframe-to-another-dataframe-in-pandas

'''
updated_vocabulary = vocab_add.merge(main_vocabulary, how='left', indicator=True)

# selecting rows that are flagged with left_only
updated_vocabulary = updated_vocabulary[updated_vocabulary._merge == 'left_only'].iloc[:,:-1]

# update main_vocabulary with only updated words
main_vocabulary = pl.concat([main_vocabulary, updated_vocabulary], ignore_index=True)

display(main_vocabulary.shape)     #  checked that it does not add duplicate rows or columns even when repeated

# save to csv
df_csv = main_vocabulary.to_csv('Kindle_scribe_vocab_updated.csv', index=False)                # index=False as otherwise adding extra index columns
print('Saved new Kindle clipping words to Kindle_scribe_vocab_updated.csv.')
'''
# Out:
# "\nupdated_vocabulary = vocab_add.merge(main_vocabulary, how='left', indicator=True)\n\n# selecting rows that are flagged with left_only\nupdated_vocabulary = updated_vocabulary[updated_vocabulary._merge == 'left_only'].iloc[:,:-1]\n\n# update main_vocabulary with only updated words\nmain_vocabulary = pl.concat([main_vocabulary, updated_vocabulary], ignore_index=True)\n\ndisplay(main_vocabulary.shape)     #  checked that it does not add duplicate rows or columns even when repeated\n\n# save to csv\ndf_csv = main_vocabulary.to_csv('Kindle_scribe_vocab_updated.csv', index=False)                # index=False as otherwise adding extra index columns\nprint('Saved new Kindle clipping words to Kindle_scribe_vocab_updated.csv.')\n"

# %%
test_vocabulary = pl.read_csv("Kindle_scribe_vocab_updated.csv")
test_vocabulary.shape
test_vocabulary
# Out:
# shape: (1_014, 2)
# ┌─────────────────────┬───────┐
# │ WORD                ┆  NOTE │
# │ ---                 ┆ ---   │
# │ str                 ┆ str   │
# ╞═════════════════════╪═══════╡
# │ abaddon             ┆ null  │
# │ abaft               ┆ null  │
# │ abba                ┆ null  │
# │ aberglaube          ┆ null  │
# │ …                   ┆ …     │
# │ torch.cuda.Stream() ┆ null  │
# │ “Small              ┆ null  │
# │ Aegyptius           ┆ null  │
# │ BYD                 ┆ null  │
# └─────────────────────┴───────┘
